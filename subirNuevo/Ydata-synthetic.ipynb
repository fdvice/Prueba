# %%
# Importación de las librerías necesarias
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
#from ydata_synthetic.synthesizers import RegularSynthesizer
from ydata_synthetic.synthesizers.regular import RegularSynthesizer
#from ydata_synthetic.evaluator import Evaluator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 8
#       6 import seaborn as sns
#       7 #from ydata_synthetic.synthesizers import RegularSynthesizer
# ----> 8 from ydata_synthetic.synthesizers.regular import RegularSynthesizer
#       9 #from ydata_synthetic.evaluator import Evaluator
#
# ModuleNotFoundError: No module named 'ydata_synthetic'

# %%
# !pip install ydata_synthetic
# Out:
# Requirement already satisfied: ydata_synthetic in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (0.8.0)
# Requirement already satisfied: pandas==1.4.* in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (1.4.4)
# Requirement already satisfied: numpy==1.23.* in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (1.23.5)
# Requirement already satisfied: scikit-learn==1.1.* in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (1.1.3)
# Requirement already satisfied: matplotlib==3.5.* in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (3.5.3)
# Requirement already satisfied: tensorflow==2.9.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (2.9.0)
# Requirement already satisfied: easydict==1.9 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (1.9)
# Requirement already satisfied: pmlb==1.0.* in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (1.0.1.post3)
# Requirement already satisfied: tqdm<5.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (4.66.4)
# Requirement already satisfied: typeguard==2.13.* in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (2.13.3)
# Requirement already satisfied: pytest==6.2.* in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from ydata_synthetic) (6.2.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from matplotlib==3.5.*->ydata_synthetic) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from matplotlib==3.5.*->ydata_synthetic) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from matplotlib==3.5.*->ydata_synthetic) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from matplotlib==3.5.*->ydata_synthetic) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from matplotlib==3.5.*->ydata_synthetic) (10.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from matplotlib==3.5.*->ydata_synthetic) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from matplotlib==3.5.*->ydata_synthetic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pandas==1.4.*->ydata_synthetic) (2024.1)
# Requirement already satisfied: requests>=2.24.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pmlb==1.0.*->ydata_synthetic) (2.30.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pmlb==1.0.*->ydata_synthetic) (6.0.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pytest==6.2.*->ydata_synthetic) (23.2.0)
# Requirement already satisfied: iniconfig in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pytest==6.2.*->ydata_synthetic) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pytest==6.2.*->ydata_synthetic) (1.5.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pytest==6.2.*->ydata_synthetic) (1.11.0)
# Requirement already satisfied: toml in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pytest==6.2.*->ydata_synthetic) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pytest==6.2.*->ydata_synthetic) (1.4.1)
# Requirement already satisfied: colorama in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pytest==6.2.*->ydata_synthetic) (0.4.6)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from scikit-learn==1.1.*->ydata_synthetic) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from scikit-learn==1.1.*->ydata_synthetic) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from scikit-learn==1.1.*->ydata_synthetic) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (1.64.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (2.9.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorflow==2.9.0->ydata_synthetic) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.9.0->ydata_synthetic) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from requests>=2.24.0->pmlb==1.0.*->ydata_synthetic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from requests>=2.24.0->pmlb==1.0.*->ydata_synthetic) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from requests>=2.24.0->pmlb==1.0.*->ydata_synthetic) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from requests>=2.24.0->pmlb==1.0.*->ydata_synthetic) (2024.6.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (3.19.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pipee\anaconda3\envs\ydata_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.0->ydata_synthetic) (3.2.2)

# %%
# 1. Generación de un dataset de ejemplo
# Crear un dataset de ejemplo con pandas
data = pd.DataFrame({
    'age': np.random.randint(18, 70, size=1000),
    'salary': np.random.randint(30000, 100000, size=1000),
    'gender': np.random.choice(['Male', 'Female'], size=1000),
    'purchase': np.random.choice(['Yes', 'No'], size=1000)
})

# Mostrar las primeras filas del dataset original
print("Dataset Original")
print(data.head())
# Out:
# Dataset Original
#    age  salary  gender purchase
# 0   68   85298  Female       No
# 1   30   30671  Female       No
# 2   35   98382    Male      Yes
# 3   56   65630  Female       No
# 4   46   36141  Female      Yes

# %%
# 2. Entrenamiento del modelo generador de datos sintéticos
# Inicializar el sintetizador
synthesizer = RegularSynthesizer()

# Registrar el tiempo de inicio del entrenamiento
start_time = time.time()

# Entrenar el sintetizador con el dataset original
synthesizer.fit(data, epochs=500)

# Registrar el tiempo de finalización del entrenamiento
end_time = time.time()

# Calcular el tiempo total de entrenamiento
training_time = end_time - start_time
print(f"Tiempo de entrenamiento: {training_time:.2f} segundos")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 2. Entrenamiento del modelo generador de datos sintéticos
#       2 # Inicializar el sintetizador
# ----> 3 synthesizer = RegularSynthesizer()
#       5 # Registrar el tiempo de inicio del entrenamiento
#       6 start_time = time.time()
#
# NameError: name 'RegularSynthesizer' is not defined

# %%
# 3. Generación de datos sintéticos
# Registrar el tiempo de inicio de la generación de datos sintéticos
start_time = time.time()

# Generar datos sintéticos
synthetic_data = synthesizer.sample(len(data))

# Registrar el tiempo de finalización de la generación de datos sintéticos
end_time = time.time()

# Calcular el tiempo total de generación
generation_time = end_time - start_time
print(f"Tiempo de generación de datos sintéticos: {generation_time:.2f} segundos")

# Mostrar las primeras filas del dataset sintético
print("Dataset Sintético")
print(synthetic_data.head())

# %%
# 4. Visualización de los datos originales y sintéticos
# Configuración de los gráficos
sns.set(style="whitegrid")

# Visualizar la distribución de la edad
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['age'], bins=20, kde=True, color='blue')
plt.title('Distribución de Edad (Original)')

plt.subplot(1, 2, 2)
sns.histplot(synthetic_data['age'], bins=20, kde=True, color='green')
plt.title('Distribución de Edad (Sintético)')
plt.tight_layout()
plt.show()

# Visualizar la distribución de salarios
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['salary'], bins=20, kde=True, color='blue')
plt.title('Distribución de Salarios (Original)')

plt.subplot(1, 2, 2)
sns.histplot(synthetic_data['salary'], bins=20, kde=True, color='green')
plt.title('Distribución de Salarios (Sintético)')
plt.tight_layout()
plt.show()

# Visualizar la distribución de género
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='gender', data=data, palette='pastel')
plt.title('Distribución de Género (Original)')

plt.subplot(1, 2, 2)
sns.countplot(x='gender', data=synthetic_data, palette='pastel')
plt.title('Distribución de Género (Sintético)')
plt.tight_layout()
plt.show()

# Visualizar la distribución de compras
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='purchase', data=data, palette='pastel')
plt.title('Distribución de Compras (Original)')

plt.subplot(1, 2, 2)
sns.countplot(x='purchase', data=synthetic_data, palette='pastel')
plt.title('Distribución de Compras (Sintético)')
plt.tight_layout()
plt.show()

# %%
# 5. Validación de los datos sintéticos generados
# Evaluar la calidad de los datos sintéticos
evaluator = Evaluator()
evaluation_report = evaluator.evaluate(data, synthetic_data)
print(f"Reporte de evaluación de la calidad de los datos sintéticos:")
print(evaluation_report)

# %%
# Importación de las librerías necesarias
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_synthetic.synthesizers import RegularSynthesizer
from ydata_synthetic.evaluator import Evaluator

# 1. Generación de un dataset de ejemplo
# Crear un dataset de ejemplo con pandas
data = pd.DataFrame({
    'age': np.random.randint(18, 70, size=1000),
    'salary': np.random.randint(30000, 100000, size=1000),
    'gender': np.random.choice(['Male', 'Female'], size=1000),
    'purchase': np.random.choice(['Yes', 'No'], size=1000)
})

# Mostrar las primeras filas del dataset original
print("Dataset Original")
print(data.head())

# 2. Entrenamiento del modelo generador de datos sintéticos
# Inicializar el sintetizador
synthesizer = RegularSynthesizer()

# Registrar el tiempo de inicio del entrenamiento
start_time = time.time()

# Entrenar el sintetizador con el dataset original
synthesizer.fit(data, epochs=500)

# Registrar el tiempo de finalización del entrenamiento
end_time = time.time()

# Calcular el tiempo total de entrenamiento
training_time = end_time - start_time
print(f"Tiempo de entrenamiento: {training_time:.2f} segundos")

# 3. Generación de datos sintéticos
# Registrar el tiempo de inicio de la generación de datos sintéticos
start_time = time.time()

# Generar datos sintéticos
synthetic_data = synthesizer.sample(len(data))

# Registrar el tiempo de finalización de la generación de datos sintéticos
end_time = time.time()

# Calcular el tiempo total de generación
generation_time = end_time - start_time
print(f"Tiempo de generación de datos sintéticos: {generation_time:.2f} segundos")

# Mostrar las primeras filas del dataset sintético
print("Dataset Sintético")
print(synthetic_data.head())

# 4. Visualización de los datos originales y sintéticos
# Configuración de los gráficos
sns.set(style="whitegrid")

# Visualizar la distribución de la edad
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['age'], bins=20, kde=True, color='blue')
plt.title('Distribución de Edad (Original)')

plt.subplot(1, 2, 2)
sns.histplot(synthetic_data['age'], bins=20, kde=True, color='green')
plt.title('Distribución de Edad (Sintético)')
plt.tight_layout()
plt.show()

# Visualizar la distribución de salarios
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['salary'], bins=20, kde=True, color='blue')
plt.title('Distribución de Salarios (Original)')

plt.subplot(1, 2, 2)
sns.histplot(synthetic_data['salary'], bins=20, kde=True, color='green')
plt.title('Distribución de Salarios (Sintético)')
plt.tight_layout()
plt.show()

# Visualizar la distribución de género
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='gender', data=data, palette='pastel')
plt.title('Distribución de Género (Original)')

plt.subplot(1, 2, 2)
sns.countplot(x='gender', data=synthetic_data, palette='pastel')
plt.title('Distribución de Género (Sintético)')
plt.tight_layout()
plt.show()

# Visualizar la distribución de compras
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='purchase', data=data, palette='pastel')
plt.title('Distribución de Compras (Original)')

plt.subplot(1, 2, 2)
sns.countplot(x='purchase', data=synthetic_data, palette='pastel')
plt.title('Distribución de Compras (Sintético)')
plt.tight_layout()
plt.show()

# 5. Validación de los datos sintéticos generados
# Evaluar la calidad de los datos sintéticos
evaluator = Evaluator()
evaluation_report = evaluator.evaluate(data, synthetic_data)
print(f"Reporte de evaluación de la calidad de los datos sintéticos:")
print(evaluation_report)

# %%
# !pip install --upgrade --force-reinstall pmlb
# Out:
# Collecting pmlb
#   Using cached pmlb-1.0.1.post3-py3-none-any.whl.metadata (1.7 kB)
# Collecting pandas>=1.0.5 (from pmlb)
#   Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Collecting requests>=2.24.0 (from pmlb)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from pmlb)
#   Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>=1.0.5->pmlb)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.0.5->pmlb)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas>=1.0.5->pmlb)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy>=1.20.3 (from pandas>=1.0.5->pmlb)
#   Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.24.0->pmlb)
#   Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.24.0->pmlb)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.24.0->pmlb)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.24.0->pmlb)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=1.0.5->pmlb)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Using cached pmlb-1.0.1.post3-py3-none-any.whl (19 kB)
# Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.8 MB 6.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.5/10.8 MB 5.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/10.8 MB 8.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.7/10.8 MB 9.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/10.8 MB 9.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/10.8 MB 10.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.2/10.8 MB 9.8 MB/s eta 0:00:01
#    --------------- ------------------------ 4.3/10.8 MB 11.4 MB/s eta 0:00:01
#    -------------------- ------------------- 5.6/10.8 MB 13.3 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.8 MB 13.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.7/10.8 MB 14.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.6/10.8 MB 15.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.8 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 18.7 MB/s eta 0:00:00
# Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl (157 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB ? eta 0:00:00
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl (99 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/14.9 MB 45.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.1/14.9 MB 43.5 MB/s eta 0:00:01
#    --------------- ------------------------ 5.7/14.9 MB 40.8 MB/s eta 0:00:01
#    -------------------- ------------------- 7.5/14.9 MB 40.3 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/14.9 MB 40.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.1/14.9 MB 38.5 MB/s eta 0:00:01
#    --------------------------------- ------ 12.5/14.9 MB 40.9 MB/s eta 0:00:01
#    ------------------------------------ --- 13.8/14.9 MB 36.4 MB/s eta 0:00:01
#    ---------------------------------------  14.9/14.9 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 32.8 MB/s eta 0:00:00
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, urllib3, tzdata, six, pyyaml, numpy, idna, charset-normalizer, certifi, requests, python-dateutil, pandas, pmlb
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.6.2
#     Uninstalling certifi-2024.6.2:
#       Successfully uninstalled certifi-2024.6.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.30.0
#     Uninstalling requests-2.30.0:
#       Successfully uninstalled requests-2.30.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
#   Attempting uninstall: pmlb
#     Found existing installation: pmlb 1.0.1.post3
#     Uninstalling pmlb-1.0.1.post3:
#       Successfully uninstalled pmlb-1.0.1.post3
# Successfully installed certifi-2024.6.2 charset-normalizer-3.3.2 idna-3.7 numpy-1.24.4 pandas-2.0.3 pmlb-1.0.1.post3 python-dateutil-2.9.0.post0 pytz-2024.1 pyyaml-6.0.1 requests-2.32.3 six-1.16.0 tzdata-2024.1 urllib3-2.2.1

# %%
# !pip install --upgrade --force-reinstall ydata_synthetic
# Out:
# Collecting ydata_synthetic
#   Using cached ydata_synthetic-1.0.1-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting requests<2.29,>=2.24.0 (from ydata_synthetic)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pandas==1.5.* (from ydata_synthetic)
#   Downloading pandas-1.5.3-cp38-cp38-win_amd64.whl.metadata (12 kB)
# Collecting numpy==1.23.* (from ydata_synthetic)
#   Using cached numpy-1.23.5-cp38-cp38-win_amd64.whl.metadata (2.3 kB)
# Collecting scikit-learn==1.2.* (from ydata_synthetic)
#   Downloading scikit_learn-1.2.2-cp38-cp38-win_amd64.whl.metadata (11 kB)
# Collecting matplotlib==3.6.* (from ydata_synthetic)
#   Downloading matplotlib-3.6.3-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Collecting tensorflow==2.11.0 (from ydata_synthetic)
#   Downloading tensorflow-2.11.0-cp38-cp38-win_amd64.whl.metadata (2.5 kB)
# Collecting tensorflow-probability==0.19.0 (from ydata_synthetic)
#   Downloading tensorflow_probability-0.19.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting easydict==1.10 (from ydata_synthetic)
#   Using cached easydict-1.10.tar.gz (6.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pmlb==1.0.* (from ydata_synthetic)
#   Using cached pmlb-1.0.1.post3-py3-none-any.whl.metadata (1.7 kB)
# Collecting tqdm<5.0 (from ydata_synthetic)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting typeguard==2.13.* (from ydata_synthetic)
#   Using cached typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting pytest==6.2.* (from ydata_synthetic)
#   Using cached pytest-6.2.5-py3-none-any.whl.metadata (7.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.6.*->ydata_synthetic)
#   Downloading contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib==3.6.*->ydata_synthetic)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.6.*->ydata_synthetic)
#   Using cached fonttools-4.53.0-cp38-cp38-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.6.*->ydata_synthetic)
#   Using cached kiwisolver-1.4.5-cp38-cp38-win_amd64.whl.metadata (6.5 kB)
# Collecting packaging>=20.0 (from matplotlib==3.6.*->ydata_synthetic)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow>=6.2.0 (from matplotlib==3.6.*->ydata_synthetic)
#   Using cached pillow-10.3.0-cp38-cp38-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.2.1 (from matplotlib==3.6.*->ydata_synthetic)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib==3.6.*->ydata_synthetic)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==1.5.*->ydata_synthetic)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pyyaml>=5.3.1 (from pmlb==1.0.*->ydata_synthetic)
#   Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
# Collecting attrs>=19.2.0 (from pytest==6.2.*->ydata_synthetic)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting iniconfig (from pytest==6.2.*->ydata_synthetic)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest==6.2.*->ydata_synthetic)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting py>=1.8.2 (from pytest==6.2.*->ydata_synthetic)
#   Using cached py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting toml (from pytest==6.2.*->ydata_synthetic)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting atomicwrites>=1.0 (from pytest==6.2.*->ydata_synthetic)
#   Using cached atomicwrites-1.4.1-py2.py3-none-any.whl
# Collecting colorama (from pytest==6.2.*->ydata_synthetic)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting scipy>=1.3.2 (from scikit-learn==1.2.*->ydata_synthetic)
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# Collecting joblib>=1.1.1 (from scikit-learn==1.2.*->ydata_synthetic)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==1.2.*->ydata_synthetic)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting tensorflow-intel==2.11.0 (from tensorflow==2.11.0->ydata_synthetic)
#   Downloading tensorflow_intel-2.11.0-cp38-cp38-win_amd64.whl.metadata (3.9 kB)
# Collecting absl-py (from tensorflow-probability==0.19.0->ydata_synthetic)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting six>=1.10.0 (from tensorflow-probability==0.19.0->ydata_synthetic)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting decorator (from tensorflow-probability==0.19.0->ydata_synthetic)
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting cloudpickle>=1.3 (from tensorflow-probability==0.19.0->ydata_synthetic)
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting gast>=0.3.2 (from tensorflow-probability==0.19.0->ydata_synthetic)
#   Using cached gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting dm-tree (from tensorflow-probability==0.19.0->ydata_synthetic)
#   Downloading dm_tree-0.1.8-cp38-cp38-win_amd64.whl.metadata (2.0 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=2.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast>=0.3.2 (from tensorflow-probability==0.19.0->ydata_synthetic)
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached h5py-3.11.0-cp38-cp38-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached protobuf-3.19.6-cp38-cp38-win_amd64.whl.metadata (807 bytes)
# Collecting setuptools (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached setuptools-70.0.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached wrapt-1.16.0-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached grpcio-1.64.1-cp38-cp38-win_amd64.whl.metadata (3.4 kB)
# Collecting tensorboard<2.12,>=2.11 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Downloading tensorboard-2.11.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.12,>=2.11.0 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Downloading keras-2.11.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp38-cp38-win_amd64.whl.metadata (14 kB)
# Collecting charset-normalizer<4,>=2 (from requests<2.29,>=2.24.0->ydata_synthetic)
#   Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<2.29,>=2.24.0->ydata_synthetic)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests<2.29,>=2.24.0->ydata_synthetic)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.9 kB ? eta -:--:--
#      ---------------------------------------- 48.9/48.9 kB 2.6 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests<2.29,>=2.24.0->ydata_synthetic)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached google_auth-2.30.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting importlib-metadata>=4.4 (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached zipp-3.19.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0->ydata_synthetic)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading ydata_synthetic-1.0.1-py2.py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.8 kB ? eta -:--:--
#    ---------------------------------------- 64.8/64.8 kB 3.6 MB/s eta 0:00:00
# Downloading matplotlib-3.6.3-cp38-cp38-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB 5.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.2 MB 7.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.2 MB 7.2 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/7.2 MB 8.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.0/7.2 MB 8.4 MB/s eta 0:00:01
#    -------------- ------------------------- 2.6/7.2 MB 9.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.2/7.2 MB 9.7 MB/s eta 0:00:01
#    --------------------- ------------------ 3.9/7.2 MB 10.5 MB/s eta 0:00:01
#    ------------------------- -------------- 4.6/7.2 MB 10.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.4/7.2 MB 11.8 MB/s eta 0:00:01
#    ------------------------------- -------- 5.7/7.2 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 6.5/7.2 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 11.8 MB/s eta 0:00:00
# Using cached numpy-1.23.5-cp38-cp38-win_amd64.whl (14.7 MB)
# Downloading pandas-1.5.3-cp38-cp38-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/11.0 MB 19.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.5/11.0 MB 19.2 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/11.0 MB 16.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.5/11.0 MB 20.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.0 MB 19.7 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/11.0 MB 20.9 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/11.0 MB 20.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.7/11.0 MB 15.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 16.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.0/11.0 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.1/11.0 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/11.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.0 MB/s eta 0:00:00
# Using cached pmlb-1.0.1.post3-py3-none-any.whl (19 kB)
# Using cached pytest-6.2.5-py3-none-any.whl (280 kB)
# Downloading scikit_learn-1.2.2-cp38-cp38-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.4/8.3 MB 28.5 MB/s eta 0:00:01
#    ------------ --------------------------- 2.6/8.3 MB 27.1 MB/s eta 0:00:01
#    ------------------- -------------------- 4.0/8.3 MB 28.2 MB/s eta 0:00:01
#    ------------------------- -------------- 5.3/8.3 MB 28.5 MB/s eta 0:00:01
#    ------------------------------- -------- 6.5/8.3 MB 27.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.9/8.3 MB 28.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 26.5 MB/s eta 0:00:00
# Downloading tensorflow-2.11.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Downloading tensorflow_probability-0.19.0-py2.py3-none-any.whl (6.7 MB)
#    ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#    ---------- ----------------------------- 1.7/6.7 MB 36.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.9/6.7 MB 30.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.7 MB 25.1 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/6.7 MB 8.7 MB/s eta 0:00:01
#    --------------------------------- ------ 5.6/6.7 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.3/6.7 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 6.3/6.7 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 6.5/6.7 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.7/6.7 MB 9.3 MB/s eta 0:00:00
# Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
# Downloading tensorflow_intel-2.11.0-cp38-cp38-win_amd64.whl (266.3 MB)
#    ---------------------------------------- 0.0/266.3 MB ? eta -:--:--
#    ---------------------------------------- 1.1/266.3 MB 22.9 MB/s eta 0:00:12
#    ---------------------------------------- 2.6/266.3 MB 27.3 MB/s eta 0:00:10
#    ---------------------------------------- 3.1/266.3 MB 28.5 MB/s eta 0:00:10
#    ---------------------------------------- 3.1/266.3 MB 28.5 MB/s eta 0:00:10
#     --------------------------------------- 4.1/266.3 MB 18.5 MB/s eta 0:00:15
#     --------------------------------------- 5.4/266.3 MB 20.3 MB/s eta 0:00:13
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.3/266.3 MB 22.3 MB/s eta 0:00:12
#    - -------------------------------------- 7.5/266.3 MB 9.4 MB/s eta 0:00:28
#    - -------------------------------------- 8.7/266.3 MB 10.3 MB/s eta 0:00:26
#    - -------------------------------------- 9.9/266.3 MB 11.1 MB/s eta 0:00:24
#    - -------------------------------------- 11.3/266.3 MB 11.5 MB/s eta 0:00:23
#    - -------------------------------------- 12.7/266.3 MB 11.5 MB/s eta 0:00:23
#    -- ------------------------------------- 13.6/266.3 MB 12.6 MB/s eta 0:00:21
toml, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, six, setuptools, pyyaml, pyparsing, pyasn1, py, protobuf, pluggy, pillow, packaging, oauthlib, numpy, MarkupSafe, kiwisolver, keras, joblib, iniconfig, idna, grpcio, gast, fonttools, decorator, cycler, colorama, cloudpickle, charset-normalizer, certifi, cachetools, attrs, atomicwrites, absl-py, werkzeug, tqdm, tensorflow-probability, scipy, rsa, requests, python-dateutil, pytest, pyasn1-modules, opt-einsum, importlib-metadata, h5py, google-pasta, contourpy, astunparse, scikit-learn, requests-oauthlib, pandas, matplotlib, markdown, google-auth, pmlb, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow, ydata_synthetic
#   Attempting uninstall: tensorboard-plugin-wit
#     Found existing installation: tensorboard-plugin-wit 1.8.1
#     Uninstalling tensorboard-plugin-wit-1.8.1:
#       Successfully uninstalled tensorboard-plugin-wit-1.8.1
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: libclang
#     Found existing installation: libclang 18.1.1
#     Uninstalling libclang-18.1.1:
#       Successfully uninstalled libclang-18.1.1
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: easydict
#     Found existing installation: easydict 1.9
#     Uninstalling easydict-1.9:
#       Successfully uninstalled easydict-1.9
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.19.2
#     Uninstalling zipp-3.19.2:
#       Successfully uninstalled zipp-3.19.2
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.43.0
#     Uninstalling wheel-0.43.0:
#       Successfully uninstalled wheel-0.43.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 2.13.3
#     Uninstalling typeguard-2.13.3:
#       Successfully uninstalled typeguard-2.13.3
#   Attempting uninstall: toml
#     Found existing installation: toml 0.10.2
#     Uninstalling toml-0.10.2:
#       Successfully uninstalled toml-0.10.2
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.4.0
#     Uninstalling termcolor-2.4.0:
#       Successfully uninstalled termcolor-2.4.0
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.31.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.31.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.31.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.6.0
#     Uninstalling pyasn1-0.6.0:
#       Successfully uninstalled pyasn1-0.6.0
#   Attempting uninstall: py
#     Found existing installation: py 1.11.0
#     Uninstalling py-1.11.0:
#       Successfully uninstalled py-1.11.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.5.0
#     Uninstalling pluggy-1.5.0:
#       Successfully uninstalled pluggy-1.5.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.2
#     Uninstalling oauthlib-3.2.2:
#       Successfully uninstalled oauthlib-3.2.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.5
#     Uninstalling kiwisolver-1.4.5:
#       Successfully uninstalled kiwisolver-1.4.5
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: iniconfig
#     Found existing installation: iniconfig 2.0.0
#     Uninstalling iniconfig-2.0.0:
#       Successfully uninstalled iniconfig-2.0.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.53.0
#     Uninstalling fonttools-4.53.0:
#       Successfully uninstalled fonttools-4.53.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.6
#     Uninstalling colorama-0.4.6:
#       Successfully uninstalled colorama-0.4.6
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.6.2
#     Uninstalling certifi-2024.6.2:
#       Successfully uninstalled certifi-2024.6.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.3
#     Uninstalling cachetools-5.3.3:
#       Successfully uninstalled cachetools-5.3.3
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: atomicwrites
#     Found existing installation: atomicwrites 1.4.1
#     Uninstalling atomicwrites-1.4.1:
#       Successfully uninstalled atomicwrites-1.4.1
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 2.1.0
#     Uninstalling absl-py-2.1.0:
#       Successfully uninstalled absl-py-2.1.0
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.3
#     Uninstalling Werkzeug-3.0.3:
#       Successfully uninstalled Werkzeug-3.0.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pytest
#     Found existing installation: pytest 6.2.5
#     Uninstalling pytest-6.2.5:
#       Successfully uninstalled pytest-6.2.5
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1_modules 0.4.0
#     Uninstalling pyasn1_modules-0.4.0:
#       Successfully uninstalled pyasn1_modules-0.4.0
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt-einsum 3.3.0
#     Uninstalling opt-einsum-3.3.0:
#       Successfully uninstalled opt-einsum-3.3.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 7.1.0
#     Uninstalling importlib_metadata-7.1.0:
#       Successfully uninstalled importlib_metadata-7.1.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.11.0
#     Uninstalling h5py-3.11.0:
#       Successfully uninstalled h5py-3.11.0
#   Attempting uninstall: google-pasta
#     Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#   Attempting uninstall: astunparse
#     Found existing installation: astunparse 1.6.3
#     Uninstalling astunparse-1.6.3:
#       Successfully uninstalled astunparse-1.6.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 2.0.0
#     Uninstalling requests-oauthlib-2.0.0:
#       Successfully uninstalled requests-oauthlib-2.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.3
#     Uninstalling matplotlib-3.5.3:
#       Successfully uninstalled matplotlib-3.5.3
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.6
#     Uninstalling Markdown-3.6:
#       Successfully uninstalled Markdown-3.6
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.30.0
#     Uninstalling google-auth-2.30.0:
#       Successfully uninstalled google-auth-2.30.0
#   Attempting uninstall: pmlb
#     Found existing installation: pmlb 1.0.1.post3
#     Uninstalling pmlb-1.0.1.post3:
#       Successfully uninstalled pmlb-1.0.1.post3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.0
#     Uninstalling tensorflow-2.9.0:
#       Successfully uninstalled tensorflow-2.9.0
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 atomicwrites-1.4.1 attrs-23.2.0 cachetools-5.3.3 certifi-2024.6.2 charset-normalizer-3.3.2 cloudpickle-3.0.0 colorama-0.4.6 contourpy-1.1.1 cycler-0.12.1 decorator-5.1.1 dm-tree-0.1.8 easydict-1.10 flatbuffers-24.3.25 fonttools-4.53.0 gast-0.4.0 google-auth-2.30.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.64.1 h5py-3.11.0 idna-3.7 importlib-metadata-7.1.0 iniconfig-2.0.0 joblib-1.4.2 keras-2.11.0 kiwisolver-1.4.5 libclang-18.1.1 markdown-3.6 matplotlib-3.6.3 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 packaging-24.1 pandas-1.5.3 pillow-10.3.0 pluggy-1.5.0 pmlb-1.0.1.post3 protobuf-3.19.6 py-1.11.0 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyparsing-3.1.2 pytest-6.2.5 python-dateutil-2.9.0.post0 pytz-2024.1 pyyaml-6.0.1 requests-2.28.2 requests-oauthlib-2.0.0 rsa-4.9 scikit-learn-1.2.2 scipy-1.10.1 setuptools-70.0.0 six-1.16.0 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.31.0 tensorflow-probability-0.19.0 termcolor-2.4.0 threadpoolctl-3.5.0 toml-0.10.2 tqdm-4.66.4 typeguard-2.13.3 typing-extensions-4.12.2 urllib3-1.26.18 werkzeug-3.0.3 wheel-0.43.0 wrapt-1.16.0 ydata_synthetic-1.0.1 zipp-3.19.2

# %%
# Import the necessary modules
from pmlb import fetch_data
from ydata_synthetic.synthesizers.regular import RegularSynthesizer
from ydata_synthetic.synthesizers import ModelParameters, TrainParameters

# Load data
data = fetch_data('adult')
num_cols = ['age', 'fnlwgt', 'capital-gain', 'capital-loss', 'hours-per-week']
cat_cols = ['workclass','education', 'education-num', 'marital-status',
                'occupation', 'relationship', 'race', 'sex', 'native-country', 'target']

# Define model and training parameters
ctgan_args = ModelParameters(batch_size=500, lr=2e-4, betas=(0.5, 0.9))
train_args = TrainParameters(epochs=501)

# Train the generator model
synth = RegularSynthesizer(modelname='ctgan', model_parameters=ctgan_args)
synth.fit(data=data, train_arguments=train_args, num_cols=num_cols, cat_cols=cat_cols)

# Generate 1000 new synthetic samples
synth_data = synth.sample(1000)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Import the necessary modules
# ----> 2 from pmlb import fetch_data
#       3 from ydata_synthetic.synthesizers.regular import RegularSynthesizer
#       4 from ydata_synthetic.synthesizers import ModelParameters, TrainParameters
#
# ModuleNotFoundError: No module named 'pmlb'

# %%
import os

# Para obtener el nombre del entorno
env_name = os.getenv('CONDA_DEFAULT_ENV')
print(f"Estás trabajando en el entorno: {env_name}")
# Out:
# Estás trabajando en el entorno: ydata_env

# %%
from ydata_synthetic import evaluation

# Imprime todas las funciones y clases en el módulo 'evaluation'
print(dir(eval))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ydata_synthetic import evaluation
#       3 # Imprime todas las funciones y clases en el módulo 'evaluation'
#       4 print(dir(eval))
#
# ModuleNotFoundError: No module named 'ydata_synthetic'
